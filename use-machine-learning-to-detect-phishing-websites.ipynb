# %%
! pip install --user -r ../input/phishing/requirements.txt

# %%
import numpy as np
import pandas as pd
# Fix the seed of the random number generator NumPy so that your project
# is reproducible as soon as you import it. If you are using separate notebooks,
# make sure you do this in each notebook.
np.random.seed(0)

# %%
# Look at the data and understand its features. The dataset is in .csv format, 
# which can be loaded using the pandas library,
# and the features (the columns of the dataset) can be extracted using pandas itself.
phishing_df = pd.read_csv('../input/phishing/Phishing.csv')
phishing_df.head()

# %%
# Take a look at the first ten rows of the dataset. The dataset has a large number of
# features, so you might want to modify the output a bit to make it fit the screen.
phishing_df.head(10)

# %%
# Find out the exact dimensions of the dataset.
phishing_df.shape

# %%
# Find out how many unique labels are in the dataset. 
# The labels of the dataset are given in the Result column.
phishing_df["Result"].unique()
